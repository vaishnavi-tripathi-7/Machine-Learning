# %%
import pickle
import numpy as np 
import pandas as pd

pipe = pickle.load(open('pipe.pkl','rb'))

# %%
test_input2 = np.array([2, 'male', 31.0, 0, 0, 10.5, 'S'],dtype=object).reshape(1,7)
pipe.predict(test_input2)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
test_df = pd.read_csv('test.csv')

features = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']

predictions = pipe.predict(test_df[features])

submission = pd.DataFrame({
    'PassengerId': test_df['PassengerId'],  # Must match sample_submission.csv
    'Survived': predictions
})

submission.to_csv('submission.csv', index=False)
print( 'done')
# Out:
# done
